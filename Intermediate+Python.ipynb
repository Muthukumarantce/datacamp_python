# %% [markdown]
# # Data Visualization

# %% [markdown]
# **Pandas Part 1**
#
# *Creating Data frames from dictionary*
#
# Each rows are observations.
# Each columns are variables in Observations.
# There will be Row labels as well

# %%
dict = {"country" : ["Brazil","Russia","India"],
       "capital" : ["Brazilia","Moscow","Delhi"],
       "sport" : ["Footbal","Rugby","Cricket"]}

import pandas as pd
bric = pd.DataFrame(dict)
#Index will change the default row labels to defined labels (Otherwise it will be sequenced from 0 to len(rows))
bric.index = ["BR","RU","IND"]
# Out:
#     capital country    sport
# 0  Brazilia  Brazil  Footbal
# 1    Moscow  Russia    Rugby
# 2     Delhi   India  Cricket

# %% [markdown]
# **Dataframes from Csv Files**

# %%
#Index col = 0 denotes first column is row header
test_data = pd.read_csv("/Users/Muthu/Downloads/avocado.csv",index_col=0)

# %% [markdown]
# **Dictionaries to Dataframes**
#
# This example has number of Vehicles in each country with the information about whether they are driving right or not

# %%
# Pre-defined lists
names = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
dr =  [True, False, False, False, True, True, True]
cpc = [809, 731, 588, 18, 200, 70, 45]

# Import pandas as pd
import pandas as pd

# Create dictionary my_dict with three key:value pairs: my_dict
my_dict = {"country":names,"drives_right":dr,"cars_per_cap":cpc}

# Build a DataFrame cars from my_dict: cars
cars = pd.DataFrame(my_dict)

# Print cars
print(cars)

# Definition of row_labels
row_labels = ['US', 'AUS', 'JPN', 'IN', 'RU', 'MOR', 'EG']

# Specify row labels of cars
cars.index=row_labels

# Print cars again
print(cars)
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %% [markdown]
# **CSVs to Dataframes**

# %%
# Import pandas as pd
import pandas as pd

# Set the index_col=0 to exclude first column as a column label
avocados = pd.read_csv('/Users/Muthu/Downloads/avocado.csv',index_col=0)

# Print out cars
print(avocados)
# Out:
#           Date  AveragePrice  Total Volume       4046       4225     4770  \
# 0   2015-12-27          1.33      64236.62    1036.74   54454.85    48.16
# 1   2015-12-20          1.35      54876.98     674.28   44638.81    58.33
# 2   2015-12-13          0.93     118220.22     794.70  109149.67   130.50
# 3   2015-12-06          1.08      78992.15    1132.00   71976.41    72.58
# 4   2015-11-29          1.28      51039.60     941.48   43838.39    75.78
# 5   2015-11-22          1.26      55979.78    1184.27   48067.99    43.61
# 6   2015-11-15          0.99      83453.76    1368.92   73672.72    93.26
# 7   2015-11-08          0.98     109428.33     703.75  101815.36    80.00
# 8   2015-11-01          1.02      99811.42    1022.15   87315.57    85.34
# 9   2015-10-25          1.07      74338.76     842.40   64757.44   113.00
# 10  2015-10-18          1.12      84843.44     924.86   75595.85   117.07
# 11  2015-10-11          1.28      64489.17    1582.03   52677.92   105.32
# ...

# %% [markdown]
# **Square Brackets**

# %%
# Import cars data
import pandas as pd
avocado = pd.read_csv("/Users/Muthu/Downloads/avocado.csv", index_col = 0)

# Print out column as Pandas Series
print(avocado["AveragePrice"])

# Print out column as Pandas DataFrame
print(avocado[["AveragePrice"]])

# Print out DataFrame with two columns
print(avocado[["Date","AveragePrice"]])

# Print out first 3 observations
print(avocado[0:3])

# Print out fourth, fifth and sixth observation
print(avocado[3:6])
# Out:
# 0     1.33
# 1     1.35
# 2     0.93
# 3     1.08
# 4     1.28
# 5     1.26
# 6     0.99
# 7     0.98
# 8     1.02
# 9     1.07
# 10    1.12
# 11    1.28
# 12    1.31
# 13    0.99
# 14    1.33
# 15    1.28
# 16    1.11
# 17    1.07
# 18    1.34
# 19    1.33
# 20    1.12
# 21    1.45
# 22    1.11
# 23    1.26
# 24    1.05
# 25    1.35
# 26    1.37
# 27    1.27
# 28    1.32
# 29    1.07
#       ...
# 6     1.56
# 7     1.53
# 8     1.61
# 9     1.63
# 10    1.59
# 11    1.51
# 0     1.60
# 1     1.73
# 2     1.63
# 3     1.46
# 4     1.49
# 5     1.64
# 6     1.47
# 7     1.41
# 8     1.80
# 9     1.83
# 10    1.82
# 11    1.48
# 0     1.62
# 1     1.56
# 2     1.56
# 3     1.54
# 4     1.57
# 5     1.56
# 6     1.57
# 7     1.63
# 8     1.71
# 9     1.87
# 10    1.93
# 11    1.62
# Name: AveragePrice, Length: 18249, dtype: float64
#     AveragePrice
# 0           1.33
# 1           1.35
# 2           0.93
# 3           1.08
# 4           1.28
# 5           1.26
# 6           0.99
# ...

# %% [markdown]
# **loc & iloc**
#
# With loc and iloc you can do practically any data selection operation on DataFrames you can think of. loc is label-based, which means that you have to specify rows and columns based on their row and column labels. iloc is integer index based, so you have to specify rows and columns by their integer index like you did in the previous exercise.

# %%
# Print out observation for Japan
print(cars)
print(cars.loc[['JPN']])
print(cars.iloc[2])

# Print out observations for Australia and Egypt
print(cars.loc[['AUS','EG']])
print(cars.iloc[[1,6]])

# Print out drives_right value of Morocco
print(cars.loc[['MOR'],['drives_right']])

# Print sub-DataFrame
print(cars.loc[['MOR','RU'],['country','drives_right']])

# Print out drives_right column as Series and use colon for full rows 
cars.loc[:,'drives_right']

# Print out drives_right column as DataFrame
cars.loc[:,['drives_right']]

print(cars)

# Print out cars_per_cap and drives_right as DataFrame
cars.loc[:,['cars_per_cap','drives_right']]
cars.iloc[:,[0,2]]
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JPN           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True
#      cars_per_cap country  drives_right
# JPN           588   Japan         False
# cars_per_cap      588
# country         Japan
# drives_right    False
# Name: JPN, dtype: object
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False
# EG             45      Egypt          True
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False
# EG             45      Egypt          True
#      drives_right
# MOR          True
#      country  drives_right
# MOR  Morocco          True
# RU    Russia          True
# ...

# %% [markdown]
#                               **Comparison Operators**
#
# **Numeric Comparisons**

# %%
# Comparison of booleans
print(True == False)

# Comparison of integers
print(-5*15 != 75)

# Comparison of strings
print("pyscript" == "PyScript")

# Compare a boolean with an integer
print(True == 1)

# Comparison of integers
x = -3 * 6
print(x >= -10)

# Comparison of strings
y = "test"
print("test" <= y)

# Comparison of booleans
print(True > False)

#Compare Arrays
# Create arrays
import numpy as np
my_house = np.array([18.0, 20.0, 10.75, 9.50])
your_house = np.array([14.0, 24.0, 14.25, 9.0])

# my_house greater than or equal to 18
print(my_house >=18)

# my_house less than your_house
print(my_house <= your_house)
# Out:
# False
# True
# False
# True
# False
# True
# True
# [ True  True False False]
# [False  True  True False]

# %% [markdown]
# **Boolean Operators**

# %%
#And Operator
#Only if both are True, it will retrieve True otherwise False
True and True
x=8
x>5 and x<12
#False and True
#True and False
x>5 and x> 12
#False and False
# Out:
#   File "<ipython-input-7-c8fecf284ef8>", line 1
#     **And Operator**
#      ^
# SyntaxError: invalid syntax

# %%
#Or Operator
#If any one of them is true, it will retrieve true and it will retrieve False when both are False
#False or False
#False or True
True or False
y=5
y<8 or y >6
#True or True
# Out:
# True

# %%
#Not Operator
not True
not False

# %% [markdown]
# # Boolean in Numpy

# %%
import numpy as np
bmi = np.array([21,23,24])
#bmi> 21
bmi > 21
#Result: array([True,True,True])
#bmi < 20
bmi < 20
#Result: array([False,False,False])
#bmi > 21 and bmi < 20 - It will fail saying truth value of an array with more than one element is ambiguous
#bmi > 21 or bmi < 20
#Use logical and for boolean operations in array
np.logical_and(bmi>21,bmi < 20)
#The above command will retrieve array of boolean values
bmi[np.logical_or(bmi>21,bmi<20)]
#The above command will retrieve array which passes the given conditions.
# Out:
# array([23, 24])
